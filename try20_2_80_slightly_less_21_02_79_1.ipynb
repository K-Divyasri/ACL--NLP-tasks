# %% [markdown]
# <a href="https://colab.research.google.com/github/K-Divyasri/ACL--NLP-tasks/blob/main/try20_2_80_slightly_less_21_02_79_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import random
import numpy as np

from tqdm import tqdm

from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


from zipfile import ZipFile

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#451 - width x 530 - height pixels

# %%
import os
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# %%
from PIL import Image

# %%
seed = 42
np.random.seed = seed
IMG_WIDTH = 224
IMG_HEIGHT = 224
IMG_CHANNELS = 3

# %%
TRAIN_PATH = '/content/drive/Shareddrives/FYP_div/dataset/dev/images1/img_683/'
TEST_PATH = '/content/drive/Shareddrives/FYP_div/dataset/dev/images1/img_683'

# %%
train_ids = next(os.walk(TRAIN_PATH))[2]

# %%
type(train_ids)
train_ids=list(train_ids)

# %%
len(train_ids)
# Out:
# 683

# %%
test_ids=train_ids

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

# %%
save_directory = "/content/drive/Shareddrives/FYP_div/assets4"
# np.save(os.path.join(save_directory, 'X_train.npy'), X_train)
# np.save(os.path.join(save_directory, 'Y_train.npy'), Y_train)

# %%
def list_files(folder_path):
    # Get a list of all files in the folder
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    # Separate files with and without file extensions
    files_with_extension = [f for f in files if '.' in f]
    files_without_extension = [os.path.splitext(f)[0] for f in files if '.' in f]

    return files_with_extension, files_without_extension

# Specify the folder path
folder_path = '/content/drive/Shareddrives/FYP_div/dataset/dev/images1/q2'

# Get the lists of files
files_with_extension, files_without_extension = list_files(folder_path)

# Print the results
print("Files with extension:", files_with_extension)
print("Files without extension:", files_without_extension)
# Out:
# Files with extension: ['clb0lbwz3dopw086u1hctar0h.jpg', 'clb0lbwz3doq0086udmw8gdc3.jpg', 'clb0lbwz2dops086ug4o06tzt.jpg', 'clb0lbwz3doqg086ufaduas6f.jpg', 'clb0lbwz3doqc086ucfhearza.jpg', 'clb0lbwz3doq8086udsxzgnde.jpg', 'clb0lbwz3doqk086uapeed55t.jpg', 'clb0lbwz3doqs086u0kqy5ut2.jpg', 'clb0lbwz3doqo086u02bq462k.jpg', 'clb0lbwz4doqw086u45hw7gnu.jpg', 'clb0lbwz4dor4086uhmzu7ldd.jpg', 'clb0lbwz4dor8086u8fvi399d.jpg', 'clb0lbwz4dor0086ufc3y7f6e.jpg', 'clb0lbwz4dorc086u9cehhyoc.jpg', 'clb0lbwz4dorg086ud6nqbukp.jpg', 'clb0lbwz5doso086uc8ik1un2.jpg', 'clb0lbwz6dot4086u0kc26h66.jpg', 'clb0lbwz5dosw086ugyyadawg.jpg', 'clb0lbwz5dot0086uaj1e75nt.jpg', 'clb0lbwz5doss086u4tzd1n48.jpg', 'clb0lbwz6dotc086udjvldd3j.jpg', 'clb0lbwz4doro086ua6fxbql5.jpg', 'clb0lbwz4dork086uaoi03vs2.jpg', 'clb0lbwz6dot8086u4alvdmla.jpg', 'clb0lbwz4dorw086ucikjguze.jpg', 'clb0lbwz6dotg086u3vp53hr9.jpg', 'clb0lbwz4dors086u3ycpgtti.jpg', 'clb0lbwz5dosg086u1bf28rey.jpg', 'clb0lbwz5dosc086u3ghm0lux.jpg', 'clb0lbwz5dos0086u
# ...

# %%
a=files_with_extension
a1=files_without_extension

# %%
len(a1)
# Out:
# 183

# %%
TRAIN_PATH
# Out:
# '/content/drive/Shareddrives/FYP_div/dataset/dev/images1/img_683/'

# %%
train_ids=test_ids=a1

# %%
len(a1)
# Out:
# 183

# %%
load_dir = '/content/drive/Shareddrives/FYP_div/out'

# %%
X_train=[]
Y_train=[]

# %%
# !pip install scikit-image

# %%
# !python -m pip install -U scikit-image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 35.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# ...

# %%
from tqdm import tqdm
import os
import numpy as np
from skimage.io import imread
from skimage.transform import rotate
from skimage import img_as_ubyte

# %%
import cv2
from skimage import exposure

# %%
from skimage.transform import resize

# %%
IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS = 224, 224, 3

# %%
mask_dir = '/content/drive/Shareddrives/FYP_div/dataset/dev/masks/'
TRAIN_PATH = '/content/drive/Shareddrives/FYP_div/dataset/dev/images/'

load_dir='/content/drive/Shareddrives/FYP_div/out/'

# %%
def preprocess_image(image_path, gamma=2.0):
    # Read image
    img = cv2.imread(image_path)

    # Check if image is loaded successfully
    if img is None:
        raise FileNotFoundError("Image not found or unable to load.")

    # Apply gamma correction
    gamma_corrected_img = np.uint8(cv2.pow(img / 255.0, gamma) * 255.0)

    return gamma_corrected_img

# %%
# Initialize arrays for training data
X_train = np.zeros((len(train_ids)*4, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids)*4, IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

# Process and augment images and masks
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_ + ".jpg"

    # Preprocess original image
    preprocessed_img = preprocess_image(path)
    img = resize(preprocessed_img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True).astype(np.uint8)

    # Load mask
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    mask_file = id_+"_mask.jpg"
    mask_ = imread(os.path.join(mask_dir, mask_file))
    mask_ = resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    if len(mask_.shape) > 2 and mask_.shape[2] > 1:
        mask_ = np.max(mask_, axis=2)
    mask_ = np.expand_dims(mask_, axis=-1)
    mask = np.maximum(mask, mask_)

    # Store original image and mask
    X_train[n] = img
    Y_train[n] = mask

    # Augment data
    for i in range(3):
        if i == 0:
            rotated_img = rotate(img, angle=45, preserve_range=True).astype(np.uint8)
            rotated_mask = rotate(mask, angle=45, preserve_range=True).astype(bool)
        elif i == 1:
            rotated_img = np.fliplr(img)
            rotated_mask = np.fliplr(mask)
        else:
            rotated_img = np.flipud(img)
            rotated_mask = np.flipud(mask)

        X_train[(i + 1) * len(train_ids) + n] = rotated_img
        Y_train[(i + 1) * len(train_ids) + n] = rotated_mask

    # Append original image without preprocessing along with its mask


# Save augmented data
np.save(os.path.join(load_dir, 'X_train_ins4.npy'), X_train)
np.save(os.path.join(load_dir, 'Y_train_ins4.npy'), Y_train)

# Load the processed images and masks from the specified paths
X_train = np.load(os.path.join(load_dir, 'X_train_ins4.npy'))
Y_train = np.load(os.path.join(load_dir, 'Y_train_ins4.npy'))

# Print some rotated images and their masks
for i in range(len(train_ids), len(train_ids) + 5):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
    print("Corresponding Mask:")
    imshow(Y_train[i][:, :, 0])
# Out:
# 100%|██████████| 183/183 [02:32<00:00,  1.20it/s]
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:

# %%
X_train = np.load(os.path.join(load_dir, 'X_train_ins3.npy'))
Y_train = np.load(os.path.join(load_dir, 'Y_train_ins3.npy'))

# %%
# Initialize arrays for training data
X_train = np.zeros((len(train_ids)*4, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids)*4, IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

# Process and augment images and masks
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_ + ".jpg"

    # Preprocess original image
    preprocessed_img = preprocess_image(path)
    img = resize(preprocessed_img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True).astype(np.uint8)

    # Load mask
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    mask_file = id_+"_mask.jpg"
    mask_ = imread(os.path.join(mask_dir, mask_file))
    mask_ = resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    if len(mask_.shape) > 2 and mask_.shape[2] > 1:
        mask_ = np.max(mask_, axis=2)
    mask_ = np.expand_dims(mask_, axis=-1)
    mask = np.maximum(mask, mask_)

    # Store original image and mask
    X_train[n] = img
    Y_train[n] = mask

    # Augment data
    for i in range(3):
        if i == 0:
            rotated_img = rotate(img, angle=45, preserve_range=True).astype(np.uint8)
            rotated_mask = rotate(mask, angle=45, preserve_range=True).astype(bool)
        elif i == 1:
            rotated_img = np.fliplr(img)
            rotated_mask = np.fliplr(mask)
        else:
            rotated_img = np.flipud(img)
            rotated_mask = np.flipud(mask)

        X_train[(i + 1) * len(train_ids) + n] = rotated_img
        Y_train[(i + 1) * len(train_ids) + n] = rotated_mask

# Save augmented data
np.save(os.path.join(load_dir, 'X_train_ins2.npy'), X_train)
np.save(os.path.join(load_dir, 'Y_train_ins2.npy'), Y_train)

# Load the processed images and masks from the specified paths
X_train = np.load(os.path.join(load_dir, 'X_train_ins2.npy'))
Y_train = np.load(os.path.join(load_dir, 'Y_train_ins2.npy'))

# Print some rotated images and their masks
for i in range(len(train_ids), len(train_ids) + 5):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
    print("Corresponding Mask:")
    imshow(Y_train[i][:, :, 0])
# Out:
# 100%|██████████| 183/183 [00:33<00:00,  5.49it/s]
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:

# %%
# Load the processed images and masks from the specified paths
X_train = np.load(os.path.join(load_dir, 'X_train_ins4.npy'))
Y_train = np.load(os.path.join(load_dir, 'Y_train_ins4.npy'))

# Print some rotated images and their masks
for i in range(len(train_ids), len(train_ids) + 5):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
    print("Corresponding Mask:")
    imshow(Y_train[i][:, :, 0])
# Out:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:

# %%
# Print some rotated images and their masks
for i in range(0, 5):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
    print("Corresponding Mask:")
    imshow(Y_train[i][:, :, 0])
# Out:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:

# %%
for i in range(0, 1):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
# Out:
# Rotated Image:

# %%
for i in range(0, 10):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
# Out:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:
# Rotated Image:

# %%
for i in range(0, 0 + 5):  # Print the first 5 rotated images
    print("Rotated Image:")
    imshow(X_train[i])
    print("Corresponding Mask:")

    imshow(Y_train[i][:, :, 0])
# Out:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:
# Rotated Image:
# Corresponding Mask:

# %%
import matplotlib.pyplot as plt

# Show a couple of original and preprocessed images
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Show original images
axes[0, 0].imshow(X_train[0])  # Original image
axes[0, 0].set_title('Original Image')
axes[0, 1].imshow(Y_train[0][:, :, 0], cmap='gray')  # Corresponding mask
axes[0, 1].set_title('Corresponding Mask')

# Show preprocessed images
axes[1, 0].imshow(X_train[len(train_ids)])  # Preprocessed image
axes[1, 0].set_title('Preprocessed Image')
axes[1, 1].imshow(Y_train[len(train_ids)][:, :, 0], cmap='gray')  # Corresponding mask
axes[1, 1].set_title('Corresponding Mask')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Function to display images
def display_image(image, title):
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Show a couple of original and preprocessed images
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Show original images
display_image(X_train[0], 'Original Image')
display_image(Y_train[0][:, :, 0], 'Corresponding Mask')

# Show preprocessed images
display_image(X_train[len(train_ids)], 'Preprocessed Image')
display_image(Y_train[len(train_ids)][:, :, 0], 'Corresponding Mask')

# %%
# # # Save the processed images and masks
# np.save(os.path.join(load_dir, 'X_train_ins1.npy'), X_train)
# np.save(os.path.join(load_dir, 'Y_train_ins1.npy'), Y_train)

# Load the processed images and masks from the specified paths
X_train = np.load(os.path.join(load_dir, 'X_train_ins4.npy'))
Y_train = np.load(os.path.join(load_dir, 'Y_train_ins4.npy'))

# %%
TEST_PATH='/content/drive/Shareddrives/FYP_div/dataset/dev/images1/img_683/'

# %%
from tqdm import tqdm

# %%
X_test = np.zeros((len(train_ids)*4, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []

# Loop over each test image
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    # path = TEST_PATH + id_ + ".jpg"

    # # Load original test image
    # img = imread(path)[:,:,:IMG_CHANNELS]
    # sizes_test.append([img.shape[0], img.shape[1]])

    # # Resize test image
    # img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

    # # Append resized test image
    # X_test.append(img)
    path = TEST_PATH + id_ + ".jpg"

    # Preprocess original image
    preprocessed_img = preprocess_image(path)
    img = resize(preprocessed_img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

    # Load mask


    # Load mask

    # Store original image and mask
    X_test[n] = img

# Convert list to numpy array
# X_test = np.array(X_test)
np.save(os.path.join(load_dir, 'X_test_inst4.npy'), X_test)

# Load the processed images and masks from the specified paths
X_test = np.load(os.path.join(load_dir, 'X_test_inst4.npy'))
# Out:
# 100%|██████████| 183/183 [01:01<00:00,  2.99it/s]

# %%
X_test = np.load(os.path.join(load_dir, 'X_test_inst4.npy'))

# %%
import matplotlib.pyplot as plt

# Assuming X_test has been loaded and contains the images

# Define a function to plot and visualize images
def plot_images(images):
    fig, axes = plt.subplots(1, 5, figsize=(20, 5))
    for i in range(5):
        axes[i].imshow(images[i])
        axes[i].axis('off')
    plt.show()

# Print 5 images from X_test
plot_images(X_test[:5])

# %%
image_x = 180
imshow(X_train[image_x])
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()

# %%
batch_size=16

# %%
train_dir='/content/drive/Shareddrives/FYP_div/dataset/dev/'
validation_dir='/content/drive/Shareddrives/FYP_div/dataset/dev/'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest')

# Validation data should not be augmented
val_datagen = ImageDataGenerator(rescale=1./255)

# Load and augment data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 6305 images belonging to 4 classes.
# Found 6305 images belonging to 4 classes.

# %%
#Build the model
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

################################
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  lambda (Lambda)             (None, 224, 224, 3)          0         ['input_1[0][0]']
#
#  conv2d (Conv2D)             (None, 224, 224, 16)         448       ['lambda[0][0]']
#
#  dropout (Dropout)           (None, 224, 224, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 112, 112, 32)         0         ['conv2d_2[0][0]']
#
# ...

# %%
# #Modelcheckpoint
# checkpointer = tf.keras.callbacks.ModelCheckpoint('model_for_nuclei.h5', verbose=1, save_best_only=True)

# callbacks = [
#         tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
#         tf.keras.callbacks.TensorBoard(log_dir='logs')]
#
# results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=25, callbacks=callbacks)

# %%
# Define the directory to store logs and model files
output_directory = '/content/drive/Shareddrives/FYP_div/out/'
os.makedirs(output_directory, exist_ok=True)  # Create the directory if it doesn't exist

# ModelCheckpoint
model_checkpoint = ModelCheckpoint(os.path.join(output_directory, 'inst_seg1.h5'), verbose=1, save_best_only=True)

# TensorBoard
tensorboard_callback = TensorBoard(log_dir=os.path.join(output_directory, 'logs'))

# EarlyStopping
early_stopping_callback = EarlyStopping(patience=2, monitor='val_loss')

# Combine all callbacks
callbacks = [early_stopping_callback, tensorboard_callback, model_checkpoint]

# Assuming 'model' is already defined
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=4, epochs=25, callbacks=callbacks)
# Out:
# Epoch 1/25
# 165/165 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9797
# Epoch 1: val_loss improved from inf to 0.07057, saving model to /content/drive/Shareddrives/FYP_div/out/inst_seg1.h5
# 165/165 [==============================] - 11s 45ms/step - loss: 0.0584 - accuracy: 0.9797 - val_loss: 0.0706 - val_accuracy: 0.9760
# Epoch 2/25
# 165/165 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9832
# Epoch 2: val_loss did not improve from 0.07057
# 165/165 [==============================] - 7s 41ms/step - loss: 0.0474 - accuracy: 0.9832 - val_loss: 0.0867 - val_accuracy: 0.9659
# Epoch 3/25
# 165/165 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9828
# Epoch 3: val_loss did not improve from 0.07057
# 165/165 [==============================] - 7s 41ms/step - loss: 0.0495 - accuracy: 0.9828 - val_loss: 0.0735 - val_accuracy: 0.9716

# %%
from keras.models import load_model
output_directory = '/content/drive/Shareddrives/FYP_div/out/'
# model = load_model(os.path.join(output_directory, 'inst_seg1.h5'))

# %%
model.save(os.path.join(output_directory, 'inst_seg1.h5'))

# Load the model
model = load_model(os.path.join(output_directory, 'inst_seg1.h5'))

# %%
from keras.models import load_model
output_directory = '/content/drive/Shareddrives/FYP_div/out/'
model = load_model(os.path.join(output_directory, 'inst_seg1.h5'))

# %%
####################################

idx = random.randint(0, len(X_train))


preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)


preds_train_t = (preds_train > 0.2).astype(np.uint8)
preds_val_t = (preds_val > 0.2).astype(np.uint8)
preds_test_t = (preds_test > 0.2).astype(np.uint8)


# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# # Perform a sanity check on some random validation samples
# ix = random.randint(0, len(preds_val_t))
# imshow(X_train[int(X_train.shape[0]*0.9):][ix])
# plt.show()
# imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
# plt.show()
# imshow(np.squeeze(preds_val_t[ix]))
# plt.show()
# Out:
# ...
# 23/23 [==============================] - 1s 48ms/step

# %%
image_x = random.randint(0, len(train_ids))
imshow(X_train[image_x])
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()

# %%
image_x = 100


plt.imshow(X_train[image_x])
plt.title('Original Image')
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()
# Display the mask on top of the original image
plt.imshow(X_train[image_x])
plt.imshow(np.squeeze(Y_train[image_x]), alpha=0.5, cmap='viridis')  # Adjust alpha for transparency
plt.title('Image with Mask Overlay')
plt.show()

# Invert the mask
inverted_mask = np.invert(np.squeeze(Y_train[image_x]))

# Display the image with the inverted mask
plt.imshow(X_train[image_x])
plt.imshow(inverted_mask, alpha=0.2, cmap='viridis')  # Adjust alpha for transparency
plt.title('Image with Inverted Mask Overlay')
plt.show()

# %%
image_x = 100

# Display the image with only the white region of the mask visible
plt.imshow(X_train[image_x])
plt.imshow(np.ma.masked_where(np.squeeze(Y_train[image_x]) == 0, np.squeeze(Y_train[image_x])), cmap='viridis', alpha=0.5)
plt.title('Image with Masked Region')
plt.show()

# %%
image_x = 100

# Create a black image of the same size as X_train[image_x]
black_image = np.zeros_like(X_train[image_x])

# Expand dimensions of the mask to match the number of channels in the image
expanded_mask = np.expand_dims(np.squeeze(Y_train[image_x]), axis=-1)

# Set the white region of the mask to the corresponding pixel values of the image
masked_image = np.where(expanded_mask == 1, X_train[image_x], black_image)

# Display the superimposed image
plt.imshow(masked_image)
plt.title('Image with Superimposed Mask')
plt.show()

# %%
idx = random.randint(0, len(X_train))
imshow(X_train[idx])
plt.show()

preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)


preds_train_t = (preds_train > 0.4).astype(np.uint8)
preds_val_t = (preds_val > 0.4).astype(np.uint8)
preds_test_t = (preds_test > 0.4).astype(np.uint8)


# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# ...
# 23/23 [==============================] - 1s 49ms/step

# %%
def calculate_iou(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred)
    union = np.logical_or(y_true, y_pred)
    iou_score = np.sum(intersection) / np.sum(union)
    return iou_score

# %%
# Calculate IoU for some random training samples
ix = random.randint(0, len(preds_train_t))
iou_train_sample = calculate_iou(np.squeeze(Y_train[ix]), np.squeeze(preds_train_t[ix]))
print("IoU for a random training sample:", iou_train_sample)

# Calculate IoU for some random validation samples
ix = random.randint(0, len(preds_val_t))
iou_val_sample = calculate_iou(np.squeeze(Y_train[int(X_train.shape[0]*0.9):][ix]), np.squeeze(preds_val_t[ix]))
print("IoU for a random validation sample:", iou_val_sample)
# Out:
# IoU for a random training sample: 0.87452663468821
# IoU for a random validation sample: 0.8885356274546474

# %%
iou_test = []

# Iterate over each image in the test dataset
for i in range(0,183):
    # Predict mask for the current test image
    pred_mask = model.predict(np.expand_dims(X_test[i], axis=0))  # Assuming 'model' is your segmentation model

    # Convert predicted mask to binary mask
    pred_mask_binary = (pred_mask > 0.72).astype(np.uint8)

    # Compute IoU for the current image
    iou = calculate_iou(np.squeeze(Y_train[i]), np.squeeze(pred_mask_binary))
    iou_test.append(iou)

# Print mean IoU for the test dataset
print("Mean IoU for test dataset:", np.mean(iou_test))
# Out:
# ...
# 1/1 [==============================] - 0s 23ms/step
# Mean IoU for test dataset: 0.7913099766447478

# %%
predict_test=model.predict(X_test,verbose=1)
# Out:
# 23/23 [==============================] - 1s 52ms/step

# %%
predict_test_t=(predict_test>0.4).astype(np.uint8)

# %%
imshow(X_test[3])
plt.show()
imshow(np.squeeze(predict_test_t[3]))
plt.show()

# %%
# Define a function to calculate IoU
def calculate_iou(y_true, y_pred):
    intersection = np.sum(np.logical_and(y_true, y_pred))
    union = np.sum(np.logical_or(y_true, y_pred))
    iou = intersection / (union + 1e-6)  # Add a small epsilon to avoid division by zero
    return iou

# %%
# Assuming you have the ground truth masks for the test dataset
TRAIN_PATH ='/content/drive/Shareddrives/FYP_div/dataset/dev/masks/'
iou_test = []

# Iterate over each image in the test dataset
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TRAIN_PATH + id_ + "_mask.jpg"  # Assuming the mask file names are derived from image file names
    true_mask = imread(path)  # Load the ground truth mask
    true_mask = resize(true_mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)  # Resize the mask if needed

    # Predict mask for the current test image
    pred_mask = model.predict(np.expand_dims(X_test[n], axis=0))  # Assuming 'model' is your segmentation model

    # Convert predicted mask to binary mask
    pred_mask_binary = (pred_mask > 0.412).astype(np.uint8)

    # Compute IoU for the current image
    #print(pred_mask_binary)
    iou = calculate_iou(true_mask, pred_mask_binary)
    iou_test.append(iou)

# Print mean IoU for the test dataset
print("Mean IoU for test dataset:", np.mean(iou_test))
# Out:
# ...
# 100%|██████████| 183/183 [00:27<00:00,  6.54it/s]
# Mean IoU for test dataset: 0.7665952833918357

# %%
# Assuming you have the ground truth masks for the train dataset
TRAIN_PATH = '/content/drive/Shareddrives/FYP_div/dataset/dev/masks/'
iou_train = []

# Iterate over each image in the train dataset
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_ + "_mask.jpg"  # Assuming the mask file names are derived from image file names
    true_mask = imread(path)  # Load the ground truth mask
    true_mask = resize(true_mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)  # Resize the mask if needed

    # Predict mask for the current train image
    preprocessed_img = preprocess_image(os.path.join('/content/drive/Shareddrives/FYP_div/dataset/dev/images/', id_ + ".jpg"))  # Assuming IMG_DIR is the directory containing images
    img = resize(preprocessed_img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True).astype(np.uint8)
    pred_mask = model.predict(np.expand_dims(img, axis=0))  # Assuming 'model' is your segmentation model

    # Convert predicted mask to binary mask
    # Convert predicted mask to binary mask
    pred_mask_binary = (pred_mask > 0.36).astype(np.uint8)

    # Compute IoU for the current image
    iou = calculate_iou(true_mask, pred_mask_binary)
    iou_test.append(iou)

    # # Store original image and mask
    # X_train[n] = img
    # Y_train[n] = true_mask

print("Mean IoU for train dataset:", np.mean(iou_train))
# Out:
# ...
# 100%|██████████| 183/183 [00:41<00:00,  4.36it/s]
# Mean IoU for train dataset: nan
